# %% [markdown]
# # Breast Cancer Wisconsin (Diagnostic) DataSet - PdFA - Project 02

# %% [markdown]
# For women, breast cancer is a hazardous condition. The patient will die if it doesn't detect the disease in the early stages. Throughout the world, it affects women frequently. Nearly 12% of women worldwide are affected by breast cancer, and the number is continually rising.
#
# Each and every patient with breast cancer is not named by the doctors. Due of their expertise in mathematics and computing power, machine learning engineers and data scientists are brought into the picture to address this.
#
#
# ## Dataset
#
# The parameters in this dataset were obtained from digital imaging of a breast tumour cell mass obtained during fine needle aspiration. In order to aid in clinical diagnosis, this investigation aims to accurately teach machine learning algorithms to distinguish between benign and malignant tumours.
#
# For each cell nucleus, ten real-valued characteristics were calculated, including:
#
# * radius (mean of distances from center to points on the perimeter)
# * texture (standard deviation of gray-scale values)
# * perimeter
# * area
# * smoothness (local variation in radius lengths)
# * compactness (perimeter^2 / area - 1.0)
# * concavity (severity of concave portions of the contour)
# * concave points (number of concave portions of the contour)
# * symmetry
# * fractal dimension ("coastline approximation" - 1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning

# %%
df = pd.read_csv('data_project.csv')# creating Dataframe
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %% [markdown]
# * datasets are linearly separable using all 30 input features
# * Number of Instances: 569

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# * There are 569 instances of data.
# * Total number of features equals 33, of which 31 is numerical, plus Id and diagnosis.
# * One feature (Unnamed: 32) has missing values in the dataset
# * There is one unique column which is ‘Id’
# * No duplicate records

# %%
df.describe().transpose()
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
# removing id and unnamed: 32 column which is not necessary for our model
df = df.drop(['id','Unnamed: 32'],axis = 1)

# %%
df.head(10)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
# 5         M        12.45         15.70           82.57      477.1
# 6         M        18.25         19.98          119.60     1040.0
# 7         M        13.71         20.83           90.20      577.9
# 8         M        13.00         21.82           87.50      519.8
# 9         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# ...

# %%
# As our dataset is balanced (around 60-40 ratio), there is no need to balance our data
df.diagnosis.value_counts(normalize = True)
# Out:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %%
sns.countplot(x = 'diagnosis', data = df); # plot the output

# %% [markdown]
# * Important summary statistics of all the numerical variables like the mean, std, min, 25%, 50%, 75%, and max values.
# * There is high variation in values in area_mean,area_worst,,perimeter_worst,perimeter_mean and area_se
# * There are many variables have median value 0.
# * The area_worst feature’s max value is 4254 and fractal_dimension_se features’ max 0.029840. This indicates we need to standardize or normalize data before visualization, feature selection, and classification.
# * Bar plot of diagnosis shows that Malignant and Benign patients ratio is 37% (212/569) and 63% (357/569) respectively.

# %% [markdown]
# # Data Visualization

# %%
# Finding correlation among features using sns' heatmap
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Above heatmap gives us correlation between all pairs of features.
# We can reduce unwanted features by taking only one feature of pairs having high degree of correlation.
# We can see a strong co-relation between - mean radius, mean perimeter and mean area as the values are 1 and 0.99 for them. So, we visualize the other plots considering these feature_names which have a strong co-relations
# Radius mean, perimeter mean, and area mean are closely associated with one another as can be seen in the heat map plot, so we can choose one of them. There is no right answer to the question of how we decide which functionality to employ.
#
# There is a correlation between compactness mean, concavity mean, and concave points mean. As a result, we can select one of them. Aside from these, we can utilise one of the linked functions radius se, perimeter se, or area se. We can choose one of radius worst, perimeter worst, or area worst because they are all connected. We can choose one of compactness worst, concavity worst, and concave points worst. We can use compactness se, concavity se, or concave points se. There is a correlation between texture mean and texture worst, thus we can utilise one of

# %%
# generate a scatter plot matrix with the mean columns only
cols = ['diagnosis',
        'radius_mean', 
        'texture_mean', 
        'perimeter_mean', 
        'area_mean', 
        'smoothness_mean', 
        'compactness_mean', 
        'concavity_mean',
        'concave points_mean', 
        'symmetry_mean', 
        'fractal_dimension_mean']

sns.pairplot(df[cols], hue='diagnosis', palette='rocket');
